# %% [markdown]
# # IOT607U Data Mining

# %% [markdown]
# ### Week 3: Data exploration and visualization

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# ![{B1DC2A97-35D1-40AF-A7C1-F5E13FBF99B4}.png](attachment:55d9605f-9076-452b-b7d8-d54450e39361.png)

# %% [markdown]
# ![image.png](attachment:1800ade0-4c6b-47ed-b2a7-6722f025a3b2.png)

# %% [markdown]
# ![image.png](attachment:881026f6-1a98-491b-9a6b-5072d62c3e22.png)

# %% [markdown]
# ![image.png](attachment:a9c00311-c149-42a3-9c4d-961cf9817e50.png)

# %% [markdown]
# ![image.png](attachment:032f893a-a8d0-4625-a8cd-f6fc70cd1393.png)

# %% [markdown]
# ![image.png](attachment:ee4110ac-0a34-4079-bc2a-64fa15c07c3a.png)

# %% [markdown]
# ![image.png](attachment:94bcaac6-3e9d-4817-bedc-4ff4362ec63e.png)

# %% [markdown]
# ![image.png](attachment:2522e290-430a-4da8-89d2-566b5ed8a794.png)
