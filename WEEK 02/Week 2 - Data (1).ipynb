# %% [markdown]
# # ECS607U Data Mining - Week 2: Data
# ## Lecture and Seminar

# %% [markdown]
# ![image.png](attachment:4ce6470b-49ff-4de2-b99c-f7117e8b1997.png)

# %% [markdown]
# ![image.png](attachment:9cbadbc9-06fb-4cac-8851-e9852075992d.png)

# %% [markdown]
# ![image.png](attachment:732c703a-ba8d-4954-9551-9820abfacd39.png)

# %% [markdown]
# ![image.png](attachment:199b5e9f-98fb-4bd9-8fe8-66299abe9f7e.png)

# %% [markdown]
# # Characteristics of Data

# %% [markdown]
# ![image.png](attachment:5c3bb110-3b95-4114-8f1b-d57b0c701aee.png)

# %% [markdown]
# ![image.png](attachment:027b59bd-a3bf-43c3-a645-313143b15441.png)

# %% [markdown]
# ![image.png](attachment:dfe21c86-df9e-4240-b4cb-9b14f866b285.png)

# %% [markdown]
# ![image.png](attachment:8c44efcf-9ac5-4573-b886-37af4e82dc37.png)

# %% [markdown]
# ![image.png](attachment:feb5dc49-961c-4199-86ec-b465315593e7.png)

# %% [markdown]
# # Data Representations

# %% [markdown]
# ## Basic Records

# %% [markdown]
# ![image.png](attachment:4c3f9cbe-7207-4e6e-8fa1-307a2807a214.png)

# %% [markdown]
# ![image.png](attachment:004a50a0-ca08-47fd-94b5-b89993cd0c36.png)

# %% [markdown]
# ![image.png](attachment:e7e33032-9af7-472d-920d-ed1c5f636fbb.png)

# %% [markdown]
# ![image.png](attachment:2db4ea44-b42d-4717-a169-d661fc756d3c.png)

# %% [markdown]
# ## Graphs

# %% [markdown]
# ![image.png](attachment:2296b0cc-3476-4419-908c-f42ba85ca244.png)

# %% [markdown]
# ![image.png](attachment:70da5744-cf82-467e-bd2e-08af2f562f4d.png)

# %% [markdown]
# ## Ordered

# %% [markdown]
# ![image.png](attachment:7953c186-fe14-43e9-a3fb-2bf8d2724099.png)

# %% [markdown]
# ![image.png](attachment:874bf690-26f4-4c99-9d9f-433c3c250022.png)

# %% [markdown]
# ![image.png](attachment:347a4205-356a-42b4-912e-7e84aa523312.png)

# %% [markdown]
# # Basic Statistical Descriptions of Data

# %% [markdown]
# ![image.png](attachment:f983d47c-25e7-4aae-9186-b9e47f5cf6b5.png)

# %% [markdown]
# ![image.png](attachment:c7e068cb-695a-40f0-b824-44f2e6d14fd0.png)

# %% [markdown]
# # Dispersion (variability, spread)

# %% [markdown]
# ![image.png](attachment:a6cb546d-00e1-4de4-86c6-4ecf7f71a0e6.png)

# %% [markdown]
# ![image.png](attachment:397d376e-24b7-4195-9d5e-e213e0eea36a.png)

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----------------------- ---------------- 7.3/12.6 MB 34.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 31.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---- ----------------------------------- 5.2/44.5 MB 26.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 11.5/44.5 MB 27.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 18.4/44.5 MB 29.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 25.7/44.5 MB 30.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 32.8/44.5 MB 31.0 MB/s eta 0:00:01
#    ------------------------------------ --- 40.4/44.5 MB 31.7 MB/s eta 0:00:01
#    ---------------------------------------  44.3/44.5 MB 31.7 MB/s eta 0:00:01
#    ---------------------------------------- 44.5/44.5 MB 28.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import scipy.stats as sts

x = np.random.normal(0,1.1000)

print([np.median(x), np.mean(x), np.std(x), sts.skew(x), sts.kurtosis(x)])
print([np.percentile(x,q) for q in [0, 25, 50, 75, 100]])

hist,bins = np.histogram(x,100)
mode_idx = np.argmax(hist)
mode = bins[mode_idx]
# Out:
# [np.float64(-0.13053214044360972), np.float64(-0.13053214044360972), np.float64(0.0), np.float64(nan), np.float64(nan)]
# [np.float64(-0.13053214044360972), np.float64(-0.13053214044360972), np.float64(-0.13053214044360972), np.float64(-0.13053214044360972), np.float64(-0.13053214044360972)]

# %% [markdown]
# # Similarity and Difference

# %% [markdown]
# ![image.png](attachment:a47ebb28-67db-42d4-985f-c15a1c663b49.png)

# %% [markdown]
# ![image.png](attachment:75e224a3-a347-43de-992e-78ca7fe84ec1.png)

# %% [markdown]
# ![image.png](attachment:ead3a1b0-214e-4e89-b126-3b131a1bfbac.png)

# %% [markdown]
# ![image.png](attachment:9e5c7aec-84ac-46bb-92c7-92d96b980db4.png)
